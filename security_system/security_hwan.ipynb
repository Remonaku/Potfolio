# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# yolov5 설치
# %cd /content/drive/MyDrive/security_hwan/
# !git clone https://github.com/ultralytics/yolov5
# Out:
# /content/drive/MyDrive/security_hwan
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16567, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 16567 (delta 23), reused 31 (delta 13), pack-reused 16522
# Receiving objects: 100% (16567/16567), 15.08 MiB | 11.83 MiB/s, done.
# Resolving deltas: 100% (11380/11380), done.
# Updating files: 100% (148/148), done.

# %%
# 설치한 yolov5 폴더로 이동
# %cd /content/drive/MyDrive/security_hwan/yolov5/
# %pip install -r requirements.txt

# %%
from glob import glob

train_img_list = glob('/content/drive/MyDrive/security_hwan/data_files/images/train/*.jpg')
test_img_list = glob('/content/drive/MyDrive/security_hwan/data_files/images/test/*.jpg')
val_img_list = glob('/content/drive/MyDrive/security_hwan/data_files/images/val/*.jpg')

print(len(train_img_list))
print(len(test_img_list))
print(len(val_img_list))
# Out:
# 234
# 11
# 22

# %%
# %cat '/content/drive/MyDrive/security_hwan/data_files/security.yaml'
# Out:
# names:
# - door
# - door_closed
# - door_frame
# - door_opened
# - foot
# - glass
# - hand
# - head
# - lower_body
# - person
# - upper_body
# - window
# - window_frame
# nc: 13
# roboflow:
#   license: CC BY 4.0
#   project: door-lsyp0
#   url: https://universe.roboflow.com/kim-taehwan/door-lsyp0/dataset/1
#   version: 1
#   workspace: kim-taehwan
# test: /content/drive/MyDrive/security_hwan/data_files/images/test/
# train: /content/drive/MyDrive/security_hwan/data_files/images/train/
# val: /content/drive/MyDrive/security_hwan/data_files/images/val/

# %%
import yaml

with open('/content/drive/MyDrive/security_hwan/data_files/security.yaml', 'r') as f:
    data = yaml.safe_load(f)

print(data)

data['train'] = '/content/drive/MyDrive/security_hwan/data_files/images/train/'
data['test'] = '/content/drive/MyDrive/security_hwan/data_files/images/test/'
data['val'] = '/content/drive/MyDrive/security_hwan/data_files/images/val/'

with open('/content/drive/MyDrive/security_hwan/data_files/security.yaml', 'w') as f:
    yaml.dump(data, f)

print(data)
# Out:
# {'train': '../train/images', 'val': '../valid/images', 'test': '../test/images', 'nc': 13, 'names': ['door', 'door_closed', 'door_frame', 'door_opened', 'foot', 'glass', 'hand', 'head', 'lower_body', 'person', 'upper_body', 'window', 'window_frame'], 'roboflow': {'workspace': 'kim-taehwan', 'project': 'door-lsyp0', 'version': 1, 'license': 'CC BY 4.0', 'url': 'https://universe.roboflow.com/kim-taehwan/door-lsyp0/dataset/1'}}
# {'train': '/content/drive/MyDrive/security_hwan/data_files/images/train/', 'val': '/content/drive/MyDrive/security_hwan/data_files/images/val/', 'test': '/content/drive/MyDrive/security_hwan/data_files/images/test/', 'nc': 13, 'names': ['door', 'door_closed', 'door_frame', 'door_opened', 'foot', 'glass', 'hand', 'head', 'lower_body', 'person', 'upper_body', 'window', 'window_frame'], 'roboflow': {'workspace': 'kim-taehwan', 'project': 'door-lsyp0', 'version': 1, 'license': 'CC BY 4.0', 'url': 'https://universe.roboflow.com/kim-taehwan/door-lsyp0/dataset/1'}}

# %%
# %cd '/content/drive/MyDrive/security_hwan/yolov5/'
# Out:
# /content/drive/MyDrive/security_hwan/yolov5

# %%
yaml_path = '/content/drive/MyDrive/security_hwan/data_files/security.yaml'
train_img_path = '/content/drive/MyDrive/security_hwan/data_files/images/train/'
test_img_path = '/content/drive/MyDrive/security_hwan/data_files/images/test/'
val_img_path = '/content/drive/MyDrive/security_hwan/data_files/images/val/'

# %%
# %pip install ultralytics
import ultralytics
from ultralytics import YOLO
model = YOLO('yolov8x.pt')

# %%
# batch 4, epochs 15

# %%
# train
model.train(data=yaml_path, epochs=15, batch=4, imgsz=640)
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...

# %%
# test
model = YOLO('/content/drive/MyDrive/security_hwan/yolov5/runs/detect/train/weights/best.pt')
result = model.predict(source=test_img_path, save=True, conf=0.5)
# Out:
# image 1/11 /content/drive/MyDrive/security_hwan/data_files/images/test/sample-101-_png.rf.fcda88183a7706c6ad1d55c0c7a1fc0d.jpg: 640x640 (no detections), 15.8ms
# image 2/11 /content/drive/MyDrive/security_hwan/data_files/images/test/sample-103-_png.rf.33f572a078d68419975408e0a0001e48.jpg: 640x640 1 person, 15.7ms
# image 3/11 /content/drive/MyDrive/security_hwan/data_files/images/test/sample-26-_png.rf.0c8a688a5bc539b5a7fa8ad877c7cc0d.jpg: 640x640 1 person, 16.2ms
# image 4/11 /content/drive/MyDrive/security_hwan/data_files/images/test/sample-27-_png.rf.881163d486a01290cf81f7565764e950.jpg: 640x640 1 person, 16.4ms
# image 5/11 /content/drive/MyDrive/security_hwan/data_files/images/test/sample-32-_png.rf.d8ac789d1b817b03ddb6f4b82d4b37ad.jpg: 640x640 (no detections), 15.6ms
# image 6/11 /content/drive/MyDrive/security_hwan/data_files/images/test/sample-40-_png.rf.29c9a9c52ce1f9a36635fb43fed2d538.jpg: 640x640 (no detections), 20.9ms
# ...

# %%
# batch 8, epochs 15

# %%
# train
model = YOLO('yolov8x.pt')
model.train(data=yaml_path, epochs=15, batch=8, imgsz=640)
# test
model = YOLO('/content/drive/MyDrive/security_hwan/yolov5/runs/detect/train2/weights/best.pt')
result = model.predict(source=test_img_path, save=True, conf=0.5)
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...

# %%
# batch 16, epochs 15

# %%
# train
model = YOLO('yolov8x.pt')
model.train(data=yaml_path, epochs=15, batch=16, imgsz=640)
# test
model = YOLO('/content/drive/MyDrive/security_hwan/yolov5/runs/detect/train3/weights/best.pt')
result = model.predict(source=test_img_path, save=True, conf=0.5)
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...

# %%
# batch 24, epochs 15

# %%
# train
model = YOLO('yolov8x.pt')
model.train(data=yaml_path, epochs=15, batch=24)
# test
model = YOLO('/content/drive/MyDrive/security_hwan/yolov5/runs/detect/train4/weights/best.pt')
result = model.predict(source=test_img_path, save=True, conf=0.5)
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...

# %%
# batch 4, epochs 30

# %%
# train
model = YOLO('yolov8x.pt')
model.train(data=yaml_path, epochs=30, batch=4)
# test
model = YOLO('/content/drive/MyDrive/security_hwan/yolov5/runs/detect/train5/weights/best.pt')
result = model.predict(source=test_img_path, save=True, conf=0.5)
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...

# %%
# batch 8, epochs 30

# %%
# train
model = YOLO('yolov8x.pt')
model.train(data=yaml_path, epochs=30, batch=8)
# test
model = YOLO('/content/drive/MyDrive/security_hwan/yolov5/runs/detect/train6/weights/best.pt')
result = model.predict(source=test_img_path, save=True, conf=0.5)

# %%
# batch 16, epochs 30

# %%
# train
model = YOLO('yolov8x.pt')
model.train(data=yaml_path, epochs=30, batch=16)
# test
model = YOLO('/content/drive/MyDrive/security_hwan/yolov5/runs/detect/train7/weights/best.pt')
result = model.predict(source=test_img_path, save=True, conf=0.5)
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...

# %%
# batch 24, epochs 30

# %%
# train
model = YOLO('yolov8x.pt')
model.train(data=yaml_path, epochs=30, batch=24)
# test
model = YOLO('/content/drive/MyDrive/security_hwan/yolov5/runs/detect/train8/weights/best.pt')
result = model.predict(source=test_img_path, save=True, conf=0.5)
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...

# %%
# batch 4, epochs 50

# %%
# train
model = YOLO('yolov8x.pt')
model.train(data=yaml_path, epochs=50, batch=4)
# test
model = YOLO('/content/drive/MyDrive/security_hwan/yolov5/runs/detect/train9/weights/best.pt')
result = model.predict(source=test_img_path, save=True, conf=0.5)
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...

# %%
# batch 8, epochs 50

# %%
# train
model = YOLO('yolov8x.pt')
model.train(data=yaml_path, epochs=50, batch=8)
# test
model = YOLO('/content/drive/MyDrive/security_hwan/yolov5/runs/detect/train10/weights/best.pt')
result = model.predict(source=test_img_path, save=True, conf=0.5)
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...

# %%
# batch 16, epochs 50

# %%
# train
model = YOLO('yolov8x.pt')
model.train(data=yaml_path, epochs=50, batch=16)
# test
model = YOLO('/content/drive/MyDrive/security_hwan/yolov5/runs/detect/train11/weights/best.pt')
result = model.predict(source=test_img_path, save=True, conf=0.5)
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...

# %%
# batch 24, epochs 50

# %%
# train
model = YOLO('yolov8x.pt')
model.train(data=yaml_path, epochs=50, batch=24)
# test
model = YOLO('/content/drive/MyDrive/security_hwan/yolov5/runs/detect/train12/weights/best.pt')
result = model.predict(source=test_img_path, save=True, conf=0.5)
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...

# %%
# batch 4, epochs 100

# %%
# train
model = YOLO('yolov8x.pt')
model.train(data=yaml_path, epochs=100, batch=4, patience=40)
# test
model = YOLO('/content/drive/MyDrive/security_hwan/yolov5/runs/detect/train13/weights/best.pt')
result = model.predict(source=test_img_path, save=True, conf=0.7)
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...

# %%
# batch 8, epochs 100

# %%
# train
model = YOLO('yolov8x.pt')
model.train(data=yaml_path, epochs=100, batch=8, patience=40)
# test
model = YOLO('/content/drive/MyDrive/security_hwan/yolov5/runs/detect/train14/weights/best.pt')
result = model.predict(source=test_img_path, save=True, conf=0.5)
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...

# %%
# batch 16, epochs 100

# %%
# train
model = YOLO('yolov8x.pt')
model.train(data=yaml_path, epochs=100, batch=16, patience=40)
# test
model = YOLO('/content/drive/MyDrive/security_hwan/yolov5/runs/detect/train15/weights/best.pt')
result = model.predict(source=test_img_path, save=True, conf=0.5)
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...

# %%
# batch 24, epochs 100

# %%
# train
model = YOLO('yolov8x.pt')
model.train(data=yaml_path, epochs=100, batch=24, patience=40)
# test
model = YOLO('/content/drive/MyDrive/security_hwan/yolov5/runs/detect/train16/weights/best.pt')
result = model.predict(source=test_img_path, save=True, conf=0.5)
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...
