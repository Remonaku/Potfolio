# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16491, done.
# remote: Counting objects: 100% (83/83), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 16491 (delta 27), reused 36 (delta 9), pack-reused 16408
# Receiving objects: 100% (16491/16491), 15.17 MiB | 12.80 MiB/s, done.
# Resolving deltas: 100% (11290/11290), done.
# Updating files: 100% (146/146), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/dl_pj2
# Out:
# /content/drive/MyDrive/dl_pj2

# %%
cd yolov5
# Out:
# /content/drive/MyDrive/dl_pj2/yolov5

# %%
pwd
# Out:
# '/content/drive/MyDrive/dl_pj2/yolov5'

# %%
# %pip install -r requirements.txt

# %%
pwd
# Out:
# '/content/drive/MyDrive/dl_pj2/yolov5'

# %%
cd ..
# Out:
# /content/drive/MyDrive/dl_pj2

# %%
# !git clone https://github.com/ssaru/convert2Yolo.git
# Out:
# Cloning into 'convert2Yolo'...
# remote: Enumerating objects: 215, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 215 (delta 38), reused 35 (delta 35), pack-reused 172
# Receiving objects: 100% (215/215), 994.67 KiB | 2.70 MiB/s, done.
# Resolving deltas: 100% (95/95), done.

# %%
cd convert2Yolo
# Out:
# /content/drive/MyDrive/dl_pj2/convert2Yolo

# %%
cd ..
# Out:
# /content/drive/MyDrive/dl_pj2

# %%
cd convert2Yolo
# Out:
# /content/drive/MyDrive/dl_pj2/convert2Yolo

# %%
# !python example.py --datasets COCO --img_path ../mainborad/data/images --label ../mainborad/labels.json --convert_output_path ../mainborad/data/labels --img_type ".jpg" --manifest_path ./ --cls_list_file ../mainborad/class.names
# Out:
# COCO Parsing:  |████████████████████████████████████████| 100.0% (212/212)  Complete
#
#
# YOLO Generating:|████████████████████████████████████████| 100.0% (106/106)  Complete
#
#
# YOLO Saving:   |████████████████████████████████████████| 100.0% (106/106)  Complete

# %%
pwd
# Out:
# '/content/drive/MyDrive/dl_pj2/yolov5'

# %%
cd ../yolov5
# Out:
# /content/drive/MyDrive/dl_pj2/yolov5

# %%
# 모델의 성능 평가 - object detection 성능 평가

# !python train.py --data ../mainborad/custom.yaml --weights yolov5m.pt
# Out:
# 2024-02-29 02:05:57.952935: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-29 02:05:57.952997: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-29 02:05:57.954516: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# 모델의 성능 평가 - object detection 성능 평가

# !python val.py --data ../mainborad/custom.yaml --weights runs/train/exp/weights/best.pt
# Out:
# val: data=../mainborad/custom.yaml, weights=['runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-287-g574331f9 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/dl_pj2/yolov5/val.py", line 438, in <module>
#     main(opt)
#   File "/content/drive/MyDrive/dl_pj2/yolov5/val.py", line 409, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/content/drive/MyDrive/dl_pj2/yolov5/val.py", line 165, in run
#     model = DetectMultiBackend(weights, device=device, dnn=dnn, data=data, fp16=half)
# ...

# %%
# yolov8
import ultralytics
from ultralytics import YOLO
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 90.1MB/s]

# %%
model.train(data='../mainborad/custom.yaml', epochs=100, patience=30, batch=5, imgsz=416)
# Out:
# Ultralytics YOLOv8.1.19 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
print(model.names)
# Out:
# {0: 'cpu', 1: 'ram'}

# %%
results = model.predict(source='../mainborad/data/images/test', save=True)
# Out:
# image 1/20 /content/drive/MyDrive/dl_pj2/yolov5/../mainborad/data/images/test/mainboard (100).jpg: 416x416 1 cpu, 1 ram, 8.3ms
# image 2/20 /content/drive/MyDrive/dl_pj2/yolov5/../mainborad/data/images/test/mainboard (101).jpg: 416x416 1 cpu, 1 ram, 9.1ms
# image 3/20 /content/drive/MyDrive/dl_pj2/yolov5/../mainborad/data/images/test/mainboard (102).jpg: 416x416 1 cpu, 1 ram, 8.4ms
# image 4/20 /content/drive/MyDrive/dl_pj2/yolov5/../mainborad/data/images/test/mainboard (103).jpg: 416x416 1 cpu, 1 ram, 8.7ms
# image 5/20 /content/drive/MyDrive/dl_pj2/yolov5/../mainborad/data/images/test/mainboard (104).jpg: 416x416 1 cpu, 1 ram, 8.7ms
# image 6/20 /content/drive/MyDrive/dl_pj2/yolov5/../mainborad/data/images/test/mainboard (105).jpg: 416x416 1 cpu, 1 ram, 8.2ms
# image 7/20 /content/drive/MyDrive/dl_pj2/yolov5/../mainborad/data/images/test/mainboard (106).jpg: 416x416 1 cpu, 1 ram, 10.0ms
# ...
