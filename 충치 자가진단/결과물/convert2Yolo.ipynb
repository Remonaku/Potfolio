# %%
# 드라이브 마운트

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# convert2yolo 설치
# %cd ..
# %cd /content/drive/MyDrive/ColabNotebooks/teeth3_project
# !git clone https://github.com/ssaru/convert2Yolo.git

# %cd convert2Yolo
# %pip install -r requirements.txt
# !pip freeze > requirements.txt
# Out:
# /content/drive/MyDrive/ColabNotebooks/teeth3_project
# fatal: destination path 'convert2Yolo' already exists and is not an empty directory.
# /content/drive/MyDrive/ColabNotebooks/teeth3_project/convert2Yolo
# ...
#   Using cached Pillow-7.2.0-cp310-cp310-linux_x86_64.whl
# ...
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# ...
#   Using cached kiwisolver-1.0.1-cp310-cp310-linux_x86_64.whl
# ...
#   Using cached matplotlib-2.2.2-cp310-cp310-linux_x86_64.whl
# ...
#   Using cached numpy-1.14.3.zip (4.9 MB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached pyparsing-2.2.0-py2.py3-none-any.whl (56 kB)
# ...
#   Using cached python_dateutil-2.7.2-py2.py3-none-any.whl (212 kB)
# ...
#   Using cached pytz-2018.4-py2.py3-none-any.whl (510 kB)
# ...
#   Using cached six-1.11.0-py2.py3-none-any.whl (10 kB)
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
# ...

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/teeth3_project/teeth3/convert2Yolo

# !python example.py --datasets COCO \
--img_path ../teeth3/data/images \
--label ../teeth3/labels.json \
--convert_output_path ../teeth3/data/labels \
--img_type ".jpg" \
--manifest_path ./ \
--cls_list_file ../teeth3/class.names
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/ColabNotebooks/teeth3_project/teeth3/convert2Yolo'
# /content/drive/MyDrive/ColabNotebooks/teeth3_project/convert2Yolo
#
# COCO Parsing:  |████████████████████████████████████████| 100.0% (1559/1559)  Complete
#
#
# YOLO Generating:|████████████████████████████████████████| 100.0% (164/164)  Complete
#
#
# YOLO Saving:   |████████████████████████████████████████| 100.0% (164/164)  Complete
